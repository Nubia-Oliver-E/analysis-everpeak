# %% [markdown]
# <a href="https://colab.research.google.com/github/Nubia-Oliver-E/analysis-everpeak/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Análisis de missingness por columna
print("=== ANÁLISIS DE DATOS FALTANTES ===")
print("\nValores faltantes por columna:")
print(df.isnull().sum())

print("\nPorcentaje de missingness por columna:")
missingness_percent = (df.isnull().sum() / len(df)) * 100
print(missingness_percent.round(2))
